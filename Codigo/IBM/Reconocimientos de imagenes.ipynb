# %%
import json
from ibm_watson import VisualRecognitionV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('7rQsElWHFIfmruOZLxeRNXiqvBEhe6LuAmJZ3rZlRTq6')
visual_recognition = VisualRecognitionV3(
    version='2018-03-19',
    authenticator=authenticator
)

visual_recognition.set_service_url('https://api.us-south.visual-recognition.watson.cloud.ibm.com/instances/087062e3-1638-4105-ac78-b9f75fd00761')

with open('../../Datos/IBM/IM1.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file=images_file,accept_language="es").get_result()
    print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "almac\u00e9n general",
#               "score": 0.678,
#               "type_hierarchy": "/edificio/tienda/almac\u00e9n general"
#             },
#             {
#               "class": "tienda",
#               "score": 0.678
#             },
#             {
#               "class": "edificio",
#               "score": 0.876
#             },
#             {
#               "class": "cena",
#               "score": 0.655,
#               "type_hierarchy": "/edificio/Restaurante/cena"
#             },
#             {
#               "class": "Restaurante",
#               "score": 0.676
#             },
#             {
#               "class": "Terraza del restaurante",
#               "score": 0.5
#             },
#             {
#               "class": "mercado",
# ...

# %%
import json
from ibm_watson import VisualRecognitionV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('7rQsElWHFIfmruOZLxeRNXiqvBEhe6LuAmJZ3rZlRTq6')
visual_recognition = VisualRecognitionV3(
    version='2018-03-19',
    authenticator=authenticator
)

visual_recognition.set_service_url('https://api.us-south.visual-recognition.watson.cloud.ibm.com/instances/087062e3-1638-4105-ac78-b9f75fd00761')

with open('../../Datos/IBM/IM2.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file=images_file,accept_language="es").get_result()
    print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "kayak",
#               "score": 0.759,
#               "type_hierarchy": "/Veh\u00edculo/oficio/Embarcaciones/Barco/Barca peque\u00f1a/kayak"
#             },
#             {
#               "class": "Barca peque\u00f1a",
#               "score": 0.883
#             },
#             {
#               "class": "Barco",
#               "score": 0.892
#             },
#             {
#               "class": "Embarcaciones",
#               "score": 0.892
#             },
#             {
#               "class": "oficio",
#               "score": 0.892
#             },
#             {
#               "class": "Veh\u00edculo",
#               "score": 0.892
#             },
#             {
#               "class": "Pirag\u00fcismo",
#               "score": 0.564,
# ...

# %%
import json
from ibm_watson import VisualRecognitionV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('7rQsElWHFIfmruOZLxeRNXiqvBEhe6LuAmJZ3rZlRTq6')
visual_recognition = VisualRecognitionV3(
    version='2018-03-19',
    authenticator=authenticator
)

visual_recognition.set_service_url('https://api.us-south.visual-recognition.watson.cloud.ibm.com/instances/087062e3-1638-4105-ac78-b9f75fd00761')

with open('../../Datos/IBM/IM3.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file=images_file,accept_language="es").get_result()
    print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "pl\u00e1tano",
#               "score": 0.562,
#               "type_hierarchy": "/fruto/pl\u00e1tano"
#             },
#             {
#               "class": "fruto",
#               "score": 0.788
#             },
#             {
#               "class": "Dieta (comida)",
#               "score": 0.528,
#               "type_hierarchy": "/comida/Dieta (comida)"
#             },
#             {
#               "class": "comida",
#               "score": 0.528
#             },
#             {
#               "class": "Mel\u00f3n verde",
#               "score": 0.5,
#               "type_hierarchy": "/fruto/Mel\u00f3n/Mel\u00f3n verde"
#             },
#             {
#               "class": "Mel\u00f3n",
#               "score": 0.501
#             },
#             {
# ...
