# %%
Variable = 0

# %%
Variable
# Out:
# 0

# %%
def suma(valor1,valor2):
    return valor1+valor2
suma(3,5)
# Out:
# 8

# %%
milista = [1,2,3,4,5]

for i in milista:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a = 1
while a < 6:
    print(a)
    a = a + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
milista = [1,2,3,4,5]

for i in milista:
    if i != 3:
        print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
milista = [1,2,3,4,5]

for i in milista:
    if i != 3:
        print(i)
    else:
        print("Es tres")
# Out:
# 1
# 2
# Es tres
# 4
# 5
